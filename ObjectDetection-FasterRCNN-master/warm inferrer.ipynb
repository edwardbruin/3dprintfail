# %%
#%%time

# Get the image file name for saving output later on.
image_name = test_image.split(os.path.sep)[-1].split('.')[0]
orig_image = cv2.imread(test_image)
frame_height, frame_width, _ = orig_image.shape

RESIZE_TO = frame_width
# orig_image = image.copy()
image_resized = resize(orig_image, RESIZE_TO)
image = image_resized.copy()
# BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = infer_transforms(image)
# Add batch dimension.
image = torch.unsqueeze(image, 0)
start_time = time.time()
with torch.no_grad():
    outputs = model(image.to(DEVICE))
end_time = time.time()

# Get the current fps.
fps = 1 / (end_time - start_time)
# Add `fps` to `total_fps`.
#total_fps += fps
# Increment frame count.
#frame_count += 1
# Load all detection to CPU for further operations.
outputs = [{k: v.to('cpu') for k, v in t.items()} for t in outputs]
# Carry further only if there are detected boxes.
if len(outputs[0]['boxes']) != 0:
    orig_image = inference_annotations(
        outputs, 
        detection_threshold, 
        CLASSES,
        COLORS, 
        orig_image, 
        image_resized,
        args
    )
    if args['show_image']:
        cv2.imshow('Prediction', orig_image)
        cv2.waitKey(1)
    if args['mpl_show']:
        plt.imshow(orig_image[:, :, ::-1])
        plt.axis('off')
        plt.show()
cv2.imwrite(f"{OUT_DIR}/{image_name}.jpg", orig_image)
#print(f"Image done...")
#print('-'*50)

#print('TEST PREDICTIONS COMPLETE')
#cv2.destroyAllWindows()
# Calculate and print the average FPS.
#avg_fps = total_fps / frame_count
#print(f"Average FPS: {avg_fps:.3f}")
print('-', end='')

# %%
import numpy as np
import cv2
import torch
import glob as glob
import os
import time
import argparse
import yaml
import matplotlib.pyplot as plt

from models.create_fasterrcnn_model import create_model
from utils.annotations import inference_annotations
from utils.general import set_infer_dir
from utils.transforms import infer_transforms, resize

import os
import subprocess
import requests
from random import choice
import cv2
import streamlink

import os
import subprocess
import requests
from random import choice
import cv2
import streamlink

from google.cloud import storage

service_account_file = 'master-magnet-414308-23a8bbb0c34f.json'
storage_client = storage.Client.from_service_account_json(service_account_file)

def upload_to_bucket(blob_name, content, bucket_name):
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)
    blob.upload_from_filename(content)
    
def repeat():
    #%%time

    # Get the image file name for saving output later on.
    image_name = test_image.split(os.path.sep)[-1].split('.')[0]
    orig_image = cv2.imread(test_image)
    frame_height, frame_width, _ = orig_image.shape
    
    RESIZE_TO = frame_width
    # orig_image = image.copy()
    image_resized = resize(orig_image, RESIZE_TO)
    image = image_resized.copy()
    # BGR to RGB
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = infer_transforms(image)
    # Add batch dimension.
    image = torch.unsqueeze(image, 0)
    start_time = time.time()
    with torch.no_grad():
        outputs = model(image.to(DEVICE))
    end_time = time.time()
    
    # Get the current fps.
    fps = 1 / (end_time - start_time)
    # Add `fps` to `total_fps`.
    #total_fps += fps
    # Increment frame count.
    #frame_count += 1
    # Load all detection to CPU for further operations.
    outputs = [{k: v.to('cpu') for k, v in t.items()} for t in outputs]
    # Carry further only if there are detected boxes.
    if len(outputs[0]['boxes']) != 0:
        orig_image = inference_annotations(
            outputs, 
            detection_threshold, 
            CLASSES,
            COLORS, 
            orig_image, 
            image_resized,
            args
        )
        if args['show_image']:
            cv2.imshow('Prediction', orig_image)
            cv2.waitKey(1)
        if args['mpl_show']:
            plt.imshow(orig_image[:, :, ::-1])
            plt.axis('off')
            plt.show()
    cv2.imwrite(f"./infer_image.jpg", orig_image)
    #print(f"Image done...")
    #print('-'*50)
    
    #print('TEST PREDICTIONS COMPLETE')
    #cv2.destroyAllWindows()
    # Calculate and print the average FPS.
    #avg_fps = total_fps / frame_count
    #print(f"Average FPS: {avg_fps:.3f}")
    print('-', end='')
    
def fetch_content_from_gcs(link):
    alp = list(map(chr, range(97, 123)))
    link = link + "?"+choice(alp)+choice(alp)+'='+choice(alp)+choice(alp)
    try:
        response = requests.get(link)
        if response.status_code == 200:
            return response.text
        else:
            return f"Error fetching content. Status code: {response.status_code}"
    except requests.RequestException as e:
        return f"Error: {e}"

args = {}
args['input'] = './output_image.jpg' # set by user per inference

args['config'] = None
args['model']= None
args['weights'] = '/mnt/c/Users/edwar/OneDrive - UTS/jupyter notebooks/42028/3dprintfail/best_model.pth'
args['mpl_show'] = None
#args['mpl_show'] = True
args['device']=torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
args['img_size'] = None
args['threshold'] = 0.3
args['no_labels'] = None
args['show_image'] = None

data_configs = None
DEVICE = args['device']
OUT_DIR = set_infer_dir()

checkpoint = torch.load(args['weights'], map_location=DEVICE)
# If config file is not given, load from model dictionary.
if data_configs is None:
    data_configs = True
    NUM_CLASSES = checkpoint['config']['NC']
    CLASSES = checkpoint['config']['CLASSES']
try:
    print('Building from model name arguments...')
    build_model = create_model[str(args['model'])]
except:
    build_model = create_model[checkpoint['model_name']]
model = build_model(num_classes=NUM_CLASSES, coco_model=False)
model.load_state_dict(checkpoint['model_state_dict'])

model.to(DEVICE).eval()

COLORS = np.random.uniform(0, 255, size=(len(CLASSES), 3))

test_image = args['input']
# Define the detection threshold any detection having
# score below this will be discarded.
detection_threshold = args['threshold']

# To count the total number of frames iterated through.
frame_count = 0
# To keep adding the frames' FPS.
total_fps = 0

gcs_link = "https://storage.googleapis.com/dl_cnn_a3_3dprintfail/link.txt"
while True:
    content = fetch_content_from_gcs(gcs_link)
    #streams = streamlink.streams(content)
    streams = streamlink.streams('https://www.twitch.tv/iamfallfromgrace')
    if "best" not in streams.keys():
        continue
    
    stream_url = streams["best"].url
        
    vcap = cv2.VideoCapture(stream_url)
    image = vcap.read()[1]
    cv2.imwrite('output_image.jpg', image)

    #change this to be an in-process function where the model can be kept in memory, ideally yolo for faster inferencing
    repeat()
    #subprocess.run(['python3', 'ObjectDetection-FasterRCNN-master/inference.py','--input','./output_image.jpg','--weights','./best_model.pth'])
    
    #foo = len(os.listdir('outputs/inference'))
    upload_to_bucket('infer_image.jpg', './infer_image.jpg', 'dl_cnn_a3_3dprintfail')
# Out:
# Building from model name arguments...
# -
# ---------------------------------------------------------------------------
# InvalidResponse                           Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/google/cloud/storage/blob.py:2637, in Blob._prep_and_do_upload(self, file_obj, rewind, size, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2636 try:
# -> 2637     created_json = self._do_upload(
#    2638         client,
#    2639         file_obj,
#    2640         content_type,
#    2641         size,
#    2642         num_retries,
#    2643         predefined_acl,
#    2644         if_generation_match,
#    2645         if_generation_not_match,
#    2646         if_metageneration_match,
#    2647         if_metageneration_not_match,
#    2648         timeout=timeout,
#    2649         checksum=checksum,
#    2650         retry=retry,
#    2651         command=command,
#    2652     )
#    2653     self._set_properties(created_json)
#
# File ~/.local/lib/python3.8/site-packages/google/cloud/storage/blob.py:2443, in Blob._do_upload(self, client, stream, content_type, size, num_retries, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2442 if size is not None and size <= _MAX_MULTIPART_SIZE:
# -> 2443     response = self._do_multipart_upload(
#    2444         client,
#    2445         stream,
#    2446         content_type,
#    2447         size,
#    2448         num_retries,
#    2449         predefined_acl,
#    2450         if_generation_match,
#    2451         if_generation_not_match,
#    2452         if_metageneration_match,
#    2453         if_metageneration_not_match,
#    2454         timeout=timeout,
#    2455         checksum=checksum,
#    2456         retry=retry,
#    2457         command=command,
#    2458     )
#    2459 else:
#
# File ~/.local/lib/python3.8/site-packages/google/cloud/storage/blob.py:1956, in Blob._do_multipart_upload(self, client, stream, content_type, size, num_retries, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    1952 upload._retry_strategy = _api_core_retry_to_resumable_media_retry(
#    1953     retry, num_retries
#    1954 )
# -> 1956 response = upload.transmit(
#    1957     transport, data, object_metadata, content_type, timeout=timeout
#    1958 )
#    1960 return response
#
# File ~/.local/lib/python3.8/site-packages/google/resumable_media/requests/upload.py:153, in MultipartUpload.transmit(self, transport, data, metadata, content_type, timeout)
#     151     return result
# --> 153 return _request_helpers.wait_and_retry(
#     154     retriable_request, self._get_status_code, self._retry_strategy
#     155 )
#
# File ~/.local/lib/python3.8/site-packages/google/resumable_media/requests/_request_helpers.py:155, in wait_and_retry(func, get_status_code, retry_strategy)
#     154 try:
# --> 155     response = func()
#     156 except _CONNECTION_ERROR_CLASSES as e:
#
# File ~/.local/lib/python3.8/site-packages/google/resumable_media/requests/upload.py:149, in MultipartUpload.transmit.<locals>.retriable_request()
#     145 result = transport.request(
#     146     method, url, data=payload, headers=headers, timeout=timeout
#     147 )
# --> 149 self._process_response(result)
#     151 return result
#
# File ~/.local/lib/python3.8/site-packages/google/resumable_media/_upload.py:125, in UploadBase._process_response(self, response)
#     124 self._finished = True
# --> 125 _helpers.require_status_code(response, (http.client.OK,), self._get_status_code)
#
# File ~/.local/lib/python3.8/site-packages/google/resumable_media/_helpers.py:108, in require_status_code(response, status_codes, get_status_code, callback)
#     107         callback()
# --> 108     raise common.InvalidResponse(
#     109         response,
#     110         "Request failed with status code",
#     111         status_code,
#     112         "Expected one of",
#     113         *status_codes
#     114     )
#     115 return status_code
#
# InvalidResponse: ('Request failed with status code', 403, 'Expected one of', <HTTPStatus.OK: 200>)
#
# During handling of the above exception, another exception occurred:
#
# Forbidden                                 Traceback (most recent call last)
# Cell In[1], line 176
#     172 repeat()
#     173 #subprocess.run(['python3', 'ObjectDetection-FasterRCNN-master/inference.py','--input','./output_image.jpg','--weights','./best_model.pth'])
#     174
#     175 #foo = len(os.listdir('outputs/inference'))
# --> 176 upload_to_bucket('infer_image.jpg', './infer_image.jpg', 'dl_cnn_a3_3dprintfail')
#
# Cell In[1], line 38, in upload_to_bucket(blob_name, content, bucket_name)
#      36 bucket = storage_client.bucket(bucket_name)
#      37 blob = bucket.blob(blob_name)
# ---> 38 blob.upload_from_filename(content)
#
# File ~/.local/lib/python3.8/site-packages/google/cloud/storage/blob.py:2959, in Blob.upload_from_filename(self, filename, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    2837 def upload_from_filename(
#    2838     self,
#    2839     filename,
#    (...)
#    2850     retry=DEFAULT_RETRY_IF_GENERATION_SPECIFIED,
#    2851 ):
#    2852     """Upload this blob's contents from the content of a named file.
#    2853
#    2854     The content type of the upload will be determined in order
#    (...)
#    2956         are respected.
#    2957     """
# -> 2959     self._handle_filename_and_upload(
#    2960         filename,
#    2961         content_type=content_type,
#    2962         num_retries=num_retries,
#    2963         client=client,
#    2964         predefined_acl=predefined_acl,
#    2965         if_generation_match=if_generation_match,
#    2966         if_generation_not_match=if_generation_not_match,
#    2967         if_metageneration_match=if_metageneration_match,
#    2968         if_metageneration_not_match=if_metageneration_not_match,
#    2969         timeout=timeout,
#    2970         checksum=checksum,
#    2971         retry=retry,
#    2972     )
#
# File ~/.local/lib/python3.8/site-packages/google/cloud/storage/blob.py:2829, in Blob._handle_filename_and_upload(self, filename, content_type, *args, **kwargs)
#    2827 with open(filename, "rb") as file_obj:
#    2828     total_bytes = os.fstat(file_obj.fileno()).st_size
# -> 2829     self._prep_and_do_upload(
#    2830         file_obj,
#    2831         content_type=content_type,
#    2832         size=total_bytes,
#    2833         *args,
#    2834         **kwargs,
#    2835     )
#
# File ~/.local/lib/python3.8/site-packages/google/cloud/storage/blob.py:2655, in Blob._prep_and_do_upload(self, file_obj, rewind, size, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2653     self._set_properties(created_json)
#    2654 except resumable_media.InvalidResponse as exc:
# -> 2655     _raise_from_invalid_response(exc)
#
# File ~/.local/lib/python3.8/site-packages/google/cloud/storage/blob.py:4847, in _raise_from_invalid_response(error)
#    4843     error_message = str(error)
#    4845 message = f"{response.request.method} {response.request.url}: {error_message}"
# -> 4847 raise exceptions.from_http_status(response.status_code, message, response=response)
#
# Forbidden: 403 POST https://storage.googleapis.com/upload/storage/v1/b/dl_cnn_a3_3dprintfail/o?uploadType=multipart: {
#   "error": {
#     "code": 403,
#     "message": "The billing account for the owning project is disabled in state closed",
#     "errors": [
#       {
#         "message": "The billing account for the owning project is disabled in state closed",
#         "domain": "global",
#         "reason": "accountDisabled",
#         "locationType": "header",
#         "location": "Authorization"
#       }
#     ]
#   }
# }
# : ('Request failed with status code', 403, 'Expected one of', <HTTPStatus.OK: 200>)
